# %% [markdown]
# # Orchestration Logic
# This notebook programmatically runs all Silver transformation notebooks in sequence.
# It becomes the single entry point for the Silver layer in Databricks Jobs.

# %%
notebooks = [
  "./crm/silver_crm_customers",
  "./crm/silver_crm_products",
  "./crm/silver_crm_sales",
  "./erp/silver_erp_customer_location",
  "./erp/silver_erp_customers",
  "./erp/silver_erp_product_category"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
